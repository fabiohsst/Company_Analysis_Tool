# %% [markdown]
# # Profile Analysis with GenAI

# %% [markdown]
# This project is a variation of the **company_analysis** project found in the same repository. While it follows a similar structure, it focuses on helping professionals streamline their networking process by summarizing a person’s background and key details.
#
# You can use this project to introduce yourself to individuals who share common interests or are working on initiatives that you’d like to join.
#
# The final report generated by the LLM includes information such as:
# - **Background**
# - **Expertise**
# - **Core Values**
# - **Leadership Style**
# - **Relevant Accomplishments**
# - **Insights for Connection**
# - **Networking Opportunities**
#
# As in the previous project, the information highlighted by the LLM is fully customizable. You can simply adjust the prompt to focus on what is most relevant to you.

# %%
# imports

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %% [markdown]
# ## Objective
#
# This project aims to:
# - Extract relevant professional profile details
# - Process and structure the gathered information
# - Utilize **GPT-4o mini** to analyze and summarize key insights
#
# ### **Workflow Overview**
#
# #### **1. Data Collection**
# The notebook retrieves the data from a primary source, such as a professional website, portfolio, blog or LinkedIn page. It then processes and structures this information into a meaningful format for further analysis.
#
# #### **2. AI-Powered Analysis**
# The structured data is analyzed using **GPT-4o mini**, which extracts insights based on predefined key business indicators.
#
# #### **3. Results and Interpretation**
# The AI-generated insights are carefully reviewed and interpreted to help users achieve their primary goal: building valuable professional connections.
#
# #### **4. Conclusion**
# By following this structured, we can uncover valuable insights into each professional’s background, expertise, and goals. These insights empower individuals and organizations to make well-informed networking decisions, discover new collaboration opportunities, and strengthen professional relationships.

# %% [markdown]
# ## 📚 Importing Necessary Libraries and APIs
#
# We start by importing the necessary libraries for data handling and LLM integration. Then, we retrieve our **OpenAI API key** to authenticate requests and define the **GPT-4o mini** model for analyzing the extracted content.

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %% [markdown]
# ## 🛠️ Data Extraction and Preparation
#
# Using **BeautifulSoup**, we create a function to extract content from a given website. We then focus on using the links found on each page to provide additional context for the LLM’s analysis.

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %% [markdown]
# ## Profile analysis

# %% [markdown]
# ## 🤖 Profile Analysis with GPT-4o Mini
#
# We use the LLM in two steps:
#
# 1. First, we pass the links extracted from the webpage (via BeautifulSoup) to the LLM and ask it to determine which links are most relevant to our goal. We also request that the results be returned in **JSON** format.
# 2. Next, a second LLM uses this JSON output to generate a comprehensive report, highlighting the following points: **Company Background, Mission and Values, Leadership and Key Figures, Workplace Culture, Job Opportunities,** and **Insights for Job Seekers**.

# %%
linkedin_profile = Website("https://www.linkedin.com/company/fairsupply-com-au-pty-limited/people/")

# %%
link_system_prompt_profile = (
    "You are provided with a list of links found on a LinkedIn profile page. "
    "Decide which of these links might be relevant for someone seeking a thorough professional profile analysis, "
    "such as links to notable achievements, projects, or other professional connections. "
    "Exclude Terms of Service, Privacy policy, or email links. "
    "You should respond in JSON as in this example:"
)
link_system_prompt_profile += """
{
    "links": [
        {"type": "relevant profile link", "url": "https://www.linkedin.com/in/john-doe"}
    ]
}
"""

# %%
print(link_system_prompt_profile)
# Out:
# You are provided with a list of links found on a LinkedIn profile page. Decide which of these links might be relevant for someone seeking a thorough professional profile analysis, such as links to notable achievements, projects, or other professional connections. Exclude Terms of Service, Privacy policy, or email links. You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "relevant profile link", "url": "https://www.linkedin.com/in/john-doe"}
#     ]
# }

# %%
def get_links_profile_prompt(website):
    user_prompt = (
        f"Here is the list of links on the website of {website.url}. "
        "Please decide which of these are relevant for a thorough professional profile analysis. "
        "Specifically, we are looking for pages or resources that help assess the individual's background, expertise, "
        "achievements, values, leadership style, or day-to-day responsibilities. "
        "Provide your response in JSON format, listing the full https URLs. "
        "Do not include Terms of Service, Privacy policy, or email links.\n"
        "Links (some might be relative links):\n"
    )
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_profile_prompt(linkedin_profile))
# Out:
# Here is the list of links on the website of https://www.linkedin.com/company/fairsupply-com-au-pty-limited/people/. Please decide which of these are relevant for a thorough professional profile analysis. Specifically, we are looking for pages or resources that help assess the individual's background, expertise, achievements, values, leadership style, or day-to-day responsibilities. Provide your response in JSON format, listing the full https URLs. Do not include Terms of Service, Privacy policy, or email links.
# Links (some might be relative links):
# /
# /checkpoint/rp/request-password-reset?session_redirect=https%3A%2F%2Fwww%2Elinkedin%2Ecom%2Fcompany%2Ffairsupply-com-au-pty-limited%2Fpeople%2F
# /signup/cold-join?session_redirect=https%3A%2F%2Fwww.linkedin.com%2Fcompany%2Ffairsupply-com-au-pty-limited%2Fpeople%2F
# /legal/user-agreement
# /legal/privacy-policy
# /legal/cookie-policy
# /legal/user-agreement?trk=d_checkpoint_lg_consumerLogin_ft_user_agreement
# /legal/privacy-policy?trk=d_checkpoint_lg_consumerLogin_ft_privacy_policy
# /help/linkedin/answer/34593?lang=en&trk=d_checkpoint_lg_consumerLogin_ft_community_guidelines
# /legal/cookie-policy?trk=d_checkpoint_lg_consumerLogin_ft_cookie_policy
# /legal/copyright-policy?trk=d_checkpoint_lg_consumerLogin_ft_copyright_policy
# /help/linkedin?trk=d_checkpoint_lg_consumerLogin_ft_send_feedback&lang=en

# %%
def get_profile_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt_profile},
            {"role": "user", "content": get_links_profile_prompt(website)}
        ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Checking links from LinkedIn on Fair Supply LinkedIn page
get_profile_links("https://www.linkedin.com/in/arne-geschke-8bb61287/")
# Out:
# {'links': [{'type': 'relevant profile link',
#    'url': 'https://au.linkedin.com/in/arne-geschke-8bb61287'},
#   {'type': 'posts link',
#    'url': 'https://www.linkedin.com/posts/arne-geschke-8bb61287_a-massive-step-for-fair-supply-as-we-are-activity-7289581656296898561-LKU2'},
#   {'type': 'posts link',
#    'url': 'https://www.linkedin.com/posts/julian-fenwick-415848_fair-supply-sustainability-summer-school-activity-7293029143137374208-4yTg'},
#   {'type': 'posts link',
#    'url': 'https://www.linkedin.com/posts/arne-geschke-8bb61287_esg-climatechange-activity-7285809882321010689-zZNh'},
#   {'type': 'posts link',
#    'url': 'https://www.linkedin.com/posts/arne-geschke-8bb61287_google-for-esg-fair-supply-raises-12m-activity-7285183552483115011-smff'},
#   {'type': 'posts link',
#    'url': 'https://www.linkedin.com/posts/benderson_this-year-at-fair-supply-has-been-one-of-activity-7275453053074350084-3FWJ'},
#   {'type': 'courses link',
#    'url': 'https://www.linkedin.com/learning/c-plus-plus-design-patterns-structural-22183029?trk=public_profile_recommended-course'},
#   {'type': 'courses link',
#    'url': 'https://www.linkedin.com/learning/time-series-modeling-in-excel-r-and-power-bi?trk=public_profile_recommended-course'},
#   {'type': 'courses link',
#    'url': 'https://www.linkedin.com/learning/machine-learning-with-logistic-regression-in-excel-r-and-power-bi?trk=public_profile_recommended-course'}]}

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
def get_all_profile_details(url):
    result = "Linkedin page:\n"
    result += Website(url).get_contents()
    links = get_profile_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_profile_details("https://www.linkedin.com/in/arne-geschke-8bb61287/"))
# Out:
# Found links: {'links': [{'type': 'relevant profile link', 'url': 'https://au.linkedin.com/in/arne-geschke-8bb61287'}, {'type': 'relevant post link', 'url': 'https://www.linkedin.com/posts/arne-geschke-8bb61287_a-massive-step-for-fair-supply-as-we-are-activity-7289581656296898561-LKU2'}, {'type': 'relevant post link', 'url': 'https://www.linkedin.com/posts/arne-geschke-8bb61287_esg-climatechange-activity-7285809882321010689-zZNh'}, {'type': 'relevant post link', 'url': 'https://www.linkedin.com/posts/arne-geschke-8bb61287_google-for-esg-fair-supply-raises-12m-activity-7285183552483115011-smff'}, {'type': 'relevant post link', 'url': 'https://www.linkedin.com/posts/julian-fenwick-415848_fair-supply-sustainability-summer-school-activity-7293029143137374208-4yTg'}, {'type': 'relevant learning course link', 'url': 'https://www.linkedin.com/learning/machine-learning-with-data-reduction-in-excel-r-and-power-bi?trk=public_profile_recommended-course'}, {'type': 'relevant learning course link', 'url': 'https://www.linkedin.com/learning/practical-database-design-implementing-responsible-data-solutions-with-sql-querying?trk=public_profile_recommended-course'}, {'type': 'relevant learning course link', 'url': 'https://www.linkedin.com/learning/from-excel-to-sql?trk=public_profile_recommended-course'}]}
# Linkedin page:
# Webpage Title:
# Arne Geschke - University of Sydney | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Sign in to view Arne’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Arne Geschke
# Sign in to view Arne’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Australia
# Contact Info
# Sign in to view Arne’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# 516 followers
# 454 connections
# See your mutual connections
# View mutual connections with Arne
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Join to view profile
# Message
# Sign in to view Arne’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# University of Sydney
# University of Sydney
# Report this profile
# About
# Experienced Environmental Researcher with a demonstrated history of working in the higher…
# see more
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# Activity
# Follow
# Sign in to view Arne’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Fair Supply's has launched their Sustainability Summer School. This masterclass has been thoughtfully designed to equip sustainability professionals…
# Fair Supply's has launched their Sustainability Summer School. This masterclass has been thoughtfully designed to equip sustainability professionals…
# Liked by
# Arne Geschke
# A massive step for Fair Supply as we are heading to Canada. Thank you Kimberly Randle and Catherine Ross for making this first trip. I am sure many…
# A massive step for Fair Supply as we are heading to Canada. Thank you Kimberly Randle and Catherine Ross for making this first trip. I am sure many…
# Shared by
# Arne Geschke
# 🇨🇦❄️ Thank you, Canada, for such a warm (and let’s be honest, freezing!) welcome.  I’m thrilled to share that Fair Supply has officially launched…
# 🇨🇦❄️ Thank you, Canada, for such a warm (and let’s be honest, freezing!) welcome.  I’m thrilled to share that Fair Supply has officially launched…
# Liked by
# Arne Geschke
# Join now to see all activity
# Experience & Education
# University of Sydney
# ******** ********* *********
# **** ******
# ***** **** ******* / **-*******
# ******* ******
# ************* (****** ********** *** ********)
# ********** ** ******
# ****** ** ********* - ***
# 2018
# -
# 2020
# ********** ** ******
# ****** ** ********** (***) ************* ****** ******** *** ******** *********
# 2009
# -
# 2012
# View Arne’s full experience
# See their title, tenure and more.
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Languages
# German
# Native or bilingual proficiency
# English
# Full professional proficiency
# French
# Elementary proficiency
# Spanish
# Elementary proficiency
# More activity by Arne
# SET and Partners launch SET Carbon to advance Thailand’s carbon data management
# SET President Asadej Kongsiri, DCCE Director-General Phirun…
# SET and Partners launch SET Carbon to advance Thailand’s carbon data management
# SET President Asadej Kongsiri, DCCE Director-General Phirun…
# Liked by
# Arne Geschke
# Five V Capital is excited to announce our investment in Digital Matter, our second investment in Fund V.
#
# Digital Matter, founded in Johannesburg in…
# Five V Capital is excited to announce our investment in Digital Matter, our second investment in Fund V.
#
# Digital Matter, founded in Johannesburg in…
# Liked by
# Arne Geschke
# Truth hurts...
#
# #ESG #climatechange
# Truth hurts...
#
# #ESG #climatechange
# Shared by
# Arne Geschke
# Very excited to be working with Five V during this next, exciting phase for Fair Supply and beyond! A big thank you to the team at Five V Capital for…
# Very excited to be working with Five V during this next, exciting phase for Fair Supply and beyond! A big thank you to the team at Five V Capital for…
# Shared by
# Arne Geschke
# I can only reiterate the words of my brilliant co-founder Kimberly Randle about our recent raise. I am feeling very humbled, honoured, and excited to…
# I can only reiterate the words of my brilliant co-founder Kimberly Randle about our recent raise. I am feeling very humbled, honoured, and excited to…
# Shared by
# Arne Geschke
# Habt ihr auch eine der wichtigsten Entscheidungen für die deutsche Demokratie verpasst?
#
# Am Donnerstag hat der Bundestag die wichtige…
# Habt ihr auch eine der wichtigsten Entscheidungen für die deutsche Demokratie verpasst?
#
# Am Donnerstag hat der Bundestag die wichtige…
# Liked by
# Arne Geschke
# This year at Fair Supply has been one of the most challenging and rewarding of my career. We’ve been able to leverage the combination of data…
# This year at Fair Supply has been one of the most challenging and rewarding of my career. We’ve been able to leverage the combination of data…
# Liked by
# Arne Geschke
# Excited to share that our proposal on #Degrowth has been successfully approved by #ARC DP! 🎉
# Grateful to be collaborating with an amazing team:…
# Excited to share that our proposal on #Degrowth has been successfully approved by #ARC DP! 🎉
# Grateful to be collaborating with an amazing team:…
# Liked by
# Arne Geschke
# View Arne’s full profile
# See who you know in common
# Get introduced
# Contact Arne directly
# Join to view full profile
# Other similar profiles
# Hassan Doosti
# Program Director in Master of Data Science and Senior Lecturer, School of Mathematical and Physical Sciences, Macquarie University
# Greater Sydney Area
# Connect
# Mehmet Yildirimoglu
# Senior Lecturer of Transport Engineering at University of Queensland, Brisbane, Australia
# Greater Brisbane Area
# Connect
# Jessica Richards
# Specialist in sports fan engagement & satisfaction. Currently researching NRLW and pathways for women in sport. Senior Lecturer in Sports Management. PhD.
# Greater Sydney Area
# Connect
# Wei Li
# Senior Lecturer. Program Director Master of International Business, The University of Sydney Business School
# Greater Sydney Area
# Connect
# Patricia Lavieri
# Senior Lecturer in Transport Engineering
# Parkville, VIC
# Connect
# Nesrine Basheer
# Applied linguist | Arabic teaching specialist
# Vancouver, BC
# Connect
# Michael Anthony Lee
# Lecturer
# Melbourne, VIC
# Connect
# Marjan Aslan
# Lecturer at University of Canberra
# Canberra
# Connect
# Samir Ghannam
# Senior Lecturer at University of Technology Sydney
# Greater Sydney Area
# Connect
# Julia Low
# Sensory Scientist, Senior Lecturer @ RMIT University
# Melbourne, VIC
# Connect
# Ulya (Pipin) Jamson
# PhD Candidate - The University of Melbourne
# Melbourne, VIC
# Connect
# Hadi Akbarzadeh Khorshidi
# Senior Research Fellow | Data Scientist
# Parkville, VIC
# Connect
# Rewati Raman Bhattarai
# Senior Lecturer at Curtin University
# Kensington, WA
# Connect
# Shirui Pan
# Gold Coast, QLD
# Connect
# Bo Pang
# Researcher
# Greater Melbourne Area
# Connect
# Dr. Farzana Aman Tanima
# Senior Lecturer at University of Wollongong & Network and Communication Leader at Alternative Accounting Research Network
# Greater Sydney Area
# Connect
# Ngoc Thanh Pham
# Doctor of  philosophy (Engineering),  IEEE Member.
# Australia
# Connect
# Ju Li Ng
# Lecturer at the University of Sydney Business School
# Sydney, NSW
# Connect
# Greg Wadley
# Senior Lecturer at The University of Melbourne
# Melbourne, VIC
# Connect
# Svetlana Stevanovic
# Senior Lecturer at Deakin University
# Waurn Ponds, VIC
# Connect
# Show more profiles
# Show fewer profiles
# Explore collaborative articles
# We’re unlocking community knowledge in a new way. Experts add insights directly into each article, started with the help of AI.
# Explore More
# Others named
# Arne Geschke
# Arne Geschke
# Geschäftsführer Kyontec GmbH
# Bonn
# 1 other named Arne Geschke is on LinkedIn
# See others named
# Arne Geschke
# Add new skills with these courses
# 3h 40m
# Using Snowflake with Tableau
# 2h
# Time Series Modeling in Excel, R, and Power BI
# 1h 7m
# Choose the Right Tool for Your Data: Python, R, or SQL
# See all courses
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# View Arne’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# relevant profile link
# Webpage Title:
# Arne Geschke - University of Sydney | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Sign in to view Arne’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Arne Geschke
# Sign in to view Arne’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Australia
# Contact Info
# Sign in to view Arne’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# 516 followers
# 454 connections
# See your mutual connections
# View mutual connections with Arne
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Join to view profile
# Message
# Sign in to view Arne’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# University of Sydney
# University of Sydney
# Report this profile
# About
# Experienced Environmental Researcher with a demonstrated history of working in the higher…
# see more
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# Activity
# Follow
# Sign in to view Arne’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Fair Supply's has launched their Sustainability Summer School. This masterclass has been thoughtfully designed to equip sustainability professionals…
# Fair Supply's has launched their Sustainability Summer School. This masterclass has been thoughtfully designed to equip sustainability professionals…
# Liked by
# Arne Geschke
# A massive step for Fair Supply as we are heading to Canada. Thank you Kimberly Randle and Catherine Ross for making this first trip. I am sure many…
# A massive step for Fair Supply as we are heading to Canada. Thank you Kimberly Randle and Catherine Ross for making this first trip. I am sure many…
# Shared by
# Arne Geschke
# 🇨🇦❄️ Thank you, Canada, for such a warm (and let’s be honest, freezing!) welcome.  I’m thrilled to share that Fair Supply has officially launched…
# 🇨🇦❄️ Thank you, Canada, for such a warm (and let’s be honest, freezing!) welcome.  I’m thrilled to share that Fair Supply has officially launched…
# Liked by
# Arne Geschke
# Join now to see all activity
# Experience & Education
# University of Sydney
# ******** ********* *********
# **** ******
# ***** **** ******* / **-*******
# ******* ******
# ************* (****** ********** *** ********)
# ********** ** ******
# ****** ** ********* - ***
# 2018
# -
# 2020
# ********** ** ******
# ****** ** ********** (***) ************* ****** ******** *** ******** *********
# 2009
# -
# 2012
# View Arne’s full experience
# See their title, tenure and more.
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Languages
# German
# Native or bilingual proficiency
# English
# Full professional proficiency
# French
# Elementary proficiency
# Spanish
# Elementary proficiency
# More activity by Arne
# SET and Partners launch SET Carbon to advance Thailand’s carbon data management
# SET President Asadej Kongsiri, DCCE Director-General Phirun…
# SET and Partners launch SET Carbon to advance Thailand’s carbon data management
# SET President Asadej Kongsiri, DCCE Director-General Phirun…
# Liked by
# Arne Geschke
# Five V Capital is excited to announce our investment in Digital Matter, our second investment in Fund V.
#
# Digital Matter, founded in Johannesburg in…
# Five V Capital is excited to announce our investment in Digital Matter, our second investment in Fund V.
#
# Digital Matter, founded in Johannesburg in…
# Liked by
# Arne Geschke
# Truth hurts...
#
# #ESG #climatechange
# Truth hurts...
#
# #ESG #climatechange
# Shared by
# Arne Geschke
# Very excited to be working with Five V during this next, exciting phase for Fair Supply and beyond! A big thank you to the team at Five V Capital for…
# Very excited to be working with Five V during this next, exciting phase for Fair Supply and beyond! A big thank you to the team at Five V Capital for…
# Shared by
# Arne Geschke
# I can only reiterate the words of my brilliant co-founder Kimberly Randle about our recent raise. I am feeling very humbled, honoured, and excited to…
# I can only reiterate the words of my brilliant co-founder Kimberly Randle about our recent raise. I am feeling very humbled, honoured, and excited to…
# Shared by
# Arne Geschke
# Habt ihr auch eine der wichtigsten Entscheidungen für die deutsche Demokratie verpasst?
#
# Am Donnerstag hat der Bundestag die wichtige…
# Habt ihr auch eine der wichtigsten Entscheidungen für die deutsche Demokratie verpasst?
#
# Am Donnerstag hat der Bundestag die wichtige…
# Liked by
# Arne Geschke
# This year at Fair Supply has been one of the most challenging and rewarding of my career. We’ve been able to leverage the combination of data…
# This year at Fair Supply has been one of the most challenging and rewarding of my career. We’ve been able to leverage the combination of data…
# Liked by
# Arne Geschke
# Excited to share that our proposal on #Degrowth has been successfully approved by #ARC DP! 🎉
# Grateful to be collaborating with an amazing team:…
# Excited to share that our proposal on #Degrowth has been successfully approved by #ARC DP! 🎉
# Grateful to be collaborating with an amazing team:…
# Liked by
# Arne Geschke
# View Arne’s full profile
# See who you know in common
# Get introduced
# Contact Arne directly
# Join to view full profile
# Other similar profiles
# Hassan Doosti
# Program Director in Master of Data Science and Senior Lecturer, School of Mathematical and Physical Sciences, Macquarie University
# Greater Sydney Area
# Connect
# Mehmet Yildirimoglu
# Senior Lecturer of Transport Engineering at University of Queensland, Brisbane, Australia
# Greater Brisbane Area
# Connect
# Jessica Richards
# Specialist in sports fan engagement & satisfaction. Currently researching NRLW and pathways for women in sport. Senior Lecturer in Sports Management. PhD.
# Greater Sydney Area
# Connect
# Wei Li
# Senior Lecturer. Program Director Master of International Business, The University of Sydney Business School
# Greater Sydney Area
# Connect
# Patricia Lavieri
# Senior Lecturer in Transport Engineering
# Parkville, VIC
# Connect
# Nesrine Basheer
# Applied linguist | Arabic teaching specialist
# Vancouver, BC
# Connect
# Michael Anthony Lee
# Lecturer
# Melbourne, VIC
# Connect
# Marjan Aslan
# Lecturer at University of Canberra
# Canberra
# Connect
# Samir Ghannam
# Senior Lecturer at University of Technology Sydney
# Greater Sydney Area
# Connect
# Julia Low
# Sensory Scientist, Senior Lecturer @ RMIT University
# Melbourne, VIC
# Connect
# Explore collaborative articles
# We’re unlocking community knowledge in a new way. Experts add insights directly into each article, started with the help of AI.
# Explore More
# Others named
# Arne Geschke
# Arne Geschke
# Geschäftsführer Kyontec GmbH
# Bonn
# 1 other named Arne Geschke is on LinkedIn
# See others named
# Arne Geschke
# Add new skills with these courses
# 1h 47m
# C++ Design Patterns: Structural
# 1h 7m
# Choose the Right Tool for Your Data: Python, R, or SQL
# 4h 53m
# Probability Foundations for Data Science
# See all courses
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# View Arne’s full profile
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# relevant post link
# Webpage Title:
# Arne Geschke on LinkedIn: A massive step for Fair Supply as we are heading to Canada. Thank you…
# Webpage Contents:
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Arne Geschke’s Post
# Arne Geschke
# Chief Data Officer and Co-Founder at FairSupply /
# Honorary Associate Professor at University of Sydney
# 2w
# Report this post
# A massive step for
# Fair Supply
# as we are heading to Canada. Thank you
# Kimberly Randle
# and
# Catherine Ross
# for making this first trip. I am sure many more will follow.
# Kimberly Randle
# Founder and CEO at FairSupply Pty Limited
# 2w
# 🇨🇦❄️ Thank you, Canada, for such a warm (and let’s be honest, freezing!) welcome.  I’m thrilled to share that Fair Supply has officially launched in Canada!
#
# We’re incredibly excited to be partnering with Canadian businesses as they navigate the Fighting Against Forced Labour and Child Labour in Supply Chains Act. It’s a privilege to support organisations committed to driving transparency in their supply chains.
#
# Walking the streets of Canada these past two weeks, I couldn’t help but feel a sense of déjà vu. It brought me back to when I first launched Fair Supply in Australia—equal parts exhilaration and trepidation. Back then, I called it being "excitrifyed," and while I think the term still fits I have never been more convicted that supply chain transparency is critical for business resilience.
#
# To the Canadian companies and individuals who’ve already shown support and interest—thank you for your trust. We’re humbled to join this incredible community and contribute to your efforts in making a meaningful impact.
# Here’s to a future of collaboration, innovation, and leadership! 🌎
# #FairSupply
# #CanadaLaunch
# #SupplyChainTransparency
# #ModernSlavery
# #EthicalLeadership
# #GlobalExpansion
# Katie Bullard
# Michelle Albanese
# Kai Shimizu
# Isobel Alice O'Connell
# Ellice Serrano
# Catherine Ross
# Fair Supply
# Sam Kroonenburg
# Patricia Fletcher ICD.D
# Katherine Hu
# Arne Geschke
# Jen Roynon
# Rayan D.
# Erik Couture
# Jackie Vullinghs
# Georgie Turner
# Crystal Russell
# Shaina Brown
# Ed Bigazzi
# Serena Grant
# Robert Banks
# Gareth W Marriott
# Rob Fyfe
# 17
# Like
# Comment
# Share
# Copy
# LinkedIn
# Facebook
# Twitter
# To view or add a comment,
# sign in
# More Relevant Posts
# Bruno Montez Carpes
# Global Executive | Private Equity | CFO | M&A | International Expansion
# 5mo
# Report this post
# 3 tips from Sir
# Jonathan Knott CMG
# on how to expand to LatAm.
#
# Interesting to know that, from his British perspective, we couldn`t agree more on the first 2 tips:
#
# 1- Markets are DIFFERENT within LatAm, profoundly different. In terms of size, level of maturity, way of doing business, governance and of course, culture and language. The landscape is a mosaic of landscapes, so pls do your homework.
# By the way, the vast majority fail on doing a good on-the-ground research. Don't be that person.
#
# 2- Building relationships is key to thrive in LatAm, and I really mean it. Latins will do business when sharing a coffee or a pint in a decompressed environment, always. We believe that this is the way we truly know people.
# Every lunch time is an opportunity!
#
# My 2 cents:
# - Take into account that LatAm is still an underserved market in terms of PE/VC, for various reasons. That contributes to a much more friendly environment whenever doing business with non-locals. Tons and tons of low-hanging-fruits opportunities.
#
# And as always, pls DM if you want to share a cup of tea or coffee in London about opportunities in LatAm. Spreading the word is our core at
# Capricornio Capital
# .
# Simon Davies
# -
# Camilla Carrapatoso
# -
# Brazilian Chamber of Commerce in GB
# -
# UK in Brazil
# -
# Capricornio Capital
# -
# Canning House
# -
# Lide UK
# Jonathan Knott CMG
# HM Trade Commissioner for Latin America and the Caribbean at UK Department for Business and Trade
# 5mo
# Three years ago, I embarked on the exciting journey of becoming HM Trade Commissioner to Latin America and the Caribbean. This experience has been nothing short of remarkable, offering a blend of rewarding challenges and incredible opportunities. As I mark this milestone, I’ve recorded a video sharing some insights for British businesses looking to explore and succeed in these diverse markets.
#
# Over the past years, I've had the privilege of visiting extraordinary countries here. Each visit deepened my appreciation for the region’s rich culture, and the warm hospitality of its people. The diversity and potential of these nations continue to inspire me, and I’m proud of the strong partnerships we've forged.
#
# Supporting UK companies in expanding their reach across Latin America and the Caribbean has been a rewarding endeavour. The connections we've made and the progress we've seen are a testament to the strong potential of this region. Here’s to many more years of collaboration and growth.
# #Trade
# #GlobalTrade
# #MarketExpansion
# #TradeRelations
# #EconomicGrowth
# 18
# Like
# Comment
# Share
# Copy
# LinkedIn
# Facebook
# Twitter
# To view or add a comment,
# sign in
# Capricornio Capital
# 187 followers
# 5mo
# Report this post
# Always good to hear from Sir
# Jonathan Knott CMG
# and our friends from
# Department for Business and Trade
# .
#
# Key takeaways:
# - LatAm is vast and different. Each market has its size, maturity, governance, culture and language. Do your research before and after you start your plans.
# - Relations are truly important in LatAm for removing friction and doing business in LatAm. Latins like to know the person behind the business, so do not hesitate to attend to lunch and happy hour invitations.
# - LatAm is yet underserved in terms of PE/VC when compared to other emerging markets. That result in big opportunities when deploying cash, as risk capital is not that abundant.
#
# Stay tuned.
# #CapricornioCapital
# #LatAm
# #Latac
# #LatamInvest
# #BrazilPrivateCapitalWeek
# #BPCW2025
# Camilla Carrapatoso
# -
# Simon Davies
# -
# Bruno Montez Carpes
# Jonathan Knott CMG
# HM Trade Commissioner for Latin America and the Caribbean at UK Department for Business and Trade
# 5mo
# Three years ago, I embarked on the exciting journey of becoming HM Trade Commissioner to Latin America and the Caribbean. This experience has been nothing short of remarkable, offering a blend of rewarding challenges and incredible opportunities. As I mark this milestone, I’ve recorded a video sharing some insights for British businesses looking to explore and succeed in these diverse markets.
#
# Over the past years, I've had the privilege of visiting extraordinary countries here. Each visit deepened my appreciation for the region’s rich culture, and the warm hospitality of its people. The diversity and potential of these nations continue to inspire me, and I’m proud of the strong partnerships we've forged.
#
# Supporting UK companies in expanding their reach across Latin America and the Caribbean has been a rewarding endeavour. The connections we've made and the progress we've seen are a testament to the strong potential of this region. Here’s to many more years of collaboration and growth.
# #Trade
# #GlobalTrade
# #MarketExpansion
# #TradeRelations
# #EconomicGrowth
# 2
# Like
# Comment
# Share
# Copy
# LinkedIn
# Facebook
# Twitter
# To view or add a comment,
# sign in
# Canadian Australian Chamber of Commerce
# 2,068 followers
# 7mo
# Edited
# Report this post
# 𝗖𝗼𝗿𝗽𝗼𝗿𝗮𝘁𝗲 𝗣𝗮𝗿𝘁𝗻𝗲𝗿 𝗛𝗶𝗴𝗵𝗹𝗶𝗴𝗵𝘁:
# Global Victoria
# 𝙄𝙣𝙨𝙥𝙞𝙧𝙞𝙣𝙜 𝙑𝙞𝙘𝙩𝙤𝙧𝙞𝙖𝙣 𝙗𝙪𝙨𝙞𝙣𝙚𝙨𝙨𝙚𝙨 𝙩𝙤 𝙜𝙤 𝙜𝙡𝙤𝙗𝙖𝙡
#
# The two-way goods trade between Victoria and Canada was AUD$1 billion in 2022-23.
# Global Victoria
# can help your business enter this competitive market.
#
# As the State Government of Victoria's trade facilitation agency and gateway to global economies and communities, Global Victoria is a diverse group of dedicated trade specialists. Their team are in-market, well connected and with a single conversation, can help your business reach its potential in international markets. Global Victoria's mission is to build skills and knowledge, connect businesses to global networks, champion Victorian exporters, and promote doing business with Victoria globally. With 23 international trade and investment offices, they have the largest global network of any Australian state or territory.
#
# 𝗟𝗲𝗮𝗿𝗻 𝗺𝗼𝗿𝗲 𝗮𝗯𝗼𝘂𝘁 𝗵𝗼𝘄 𝗚𝗹𝗼𝗯𝗮𝗹 𝗩𝗶𝗰𝘁𝗼𝗿𝗶𝗮 𝗰𝗮𝗻 𝗵𝗲𝗹𝗽 𝘆𝗼𝘂𝗿 𝗯𝘂𝘀𝗶𝗻𝗲𝘀𝘀 𝗴𝗼 𝗴𝗹𝗼𝗯𝗮𝗹:
# https://lnkd.in/gvYfinqa
# -
# #GlobalBusiness
# #TradeFacilitation
# #ExportSuccess
# #InternationalTrade
# #VictoriaAustralia
# …more
# Global Victoria's Services
# https://www.youtube.com/
# 12
# Like
# Comment
# Share
# Copy
# LinkedIn
# Facebook
# Twitter
# To view or add a comment,
# sign in
# Rod Morgan
# 2mo
# Report this post
# A fabulous conference event coming up in April 2025!
# International Lean Six Sigma Institute (ILSSI)
# 's 2025 conference to be held in beautiful Jersey, Channel Islands. Be sure to watch the video and check out the conference details. EARLY BIRD pricing available until November 30, 2024!
# RPM-Academy
# #lean
# #leansixsogma
# #operationalexcellence
# #digitaltransformation
# #agile
# #artificialintelligence
# #ai
# #conference
# #annualconference
# #leanconference
# #rpmacademy
# International Lean Six Sigma Institute (ILSSI)
# 16,707 followers
# 2mo
# Edited
# The beautiful island of Jersey 🇯🇪 sits 14 miles (22 kilometres) from the French coast and 85 miles (137 kilometres) south of the coast of England.
#
# The population of Jersey is 104,000 and its GDP is £6.6 billion 💷
#
# Jersey is a British Crown Dependency, and is defended and internationally represented by the UK government🇬🇧.
#
# We hope you will take this opportunity to visit Jersey in April 2025 for the International Lean Six Sigma Conference in the @
# Radisson Blu
# Waterfront Hotel, Jersey.
#
# Early-Bird tickets for sale until November 30th at :
# https://lnkd.in/eN_hqv-W
# More information at :
# https://lnkd.in/dE5Fjsf8
# Thank you to
# Jersey Business
# ,
# Radisson Hotel Group
# ,
# SigmaXL
# ,
# Rod Morgan
# ,
# Velresco Group Ltd (Accredited Partner of ILSSI)
# ,
# JRC Learn to be Lean
# for their support 🙏
# Like
# Comment
# Share
# Copy
# LinkedIn
# Facebook
# Twitter
# To view or add a comment,
# sign in
# Jonas Busse
# Director, Global Sales | RIM logistics, ltd.
# 9mo
# Report this post
# Trading between U.S. 🇺🇸 and Canada 🇨🇦 Join our Round Table May 15th at 10 - 11 am CDT to learn from leading industry experts around Canada’s upcoming CARM (CBSA Assessment and Revenue Management ) import process which are going live October, 2024.
# #canadaustrade
# #crossborder
# #logistics
# #transportation
# #ONERIM
# RIM logistics, ltd
# 6,461 followers
# 9mo
# Please join us for RIM’s upcoming Round Table Event: Canada, CARM, and its Impact to Your Business in 2024 and Beyond, which will be hosted by our Director of Sales,
# Donna Thomas
# . We will be discussing current Canadian supply chain factors, CARM and its impact to your business, and so much more.
#
# We have an outstanding lineup of guest speakers that include the following:
#
# ⭐️
# Daniel Ujczo
# , Senior Counsel, Thompson Hine LLP
# ⭐️
# Andrea van Vugt
# , COO and Practice Lead, Trade, Wellington Advocacy
# ⭐️
# Jan Scazighino
# , Consul, Sr. Trade Commissioner, Consulate General of Canada, Detroit
# ⭐️
# Tim Wessel
# , Managing Director, Europe, RIM logistics, ltd.
#
# Registration is required to attend, so please make sure to register via the link below. We hope to see you there!
# #Canada
# #supplychainsolutions
# #ONERIM
# https://lnkd.in/gpKh-5W9
# 2
# Like
# Comment
# Share
# Copy
# LinkedIn
# Facebook
# Twitter
# To view or add a comment,
# sign in
# Sharon Hammond (FCILT)
# Head of Distribution & Transport at B&M Retail
# 2mo
# Report this post
# Fantastic news here…. 👍👍👍
#
# Last week, we announced the exciting news that we’ll be opening a new Imports Centre in Ellesmere Port. This state-of-the-art, 675,000-square-foot facility will streamline our inbound shipping container flow and optimise the capacity of our five existing Distribution Centres, helping our UK stores serve millions of customers right across the country.
#
# We’re laying firm foundations to deliver our goal of having no fewer than 1,200 B&M stores across the UK. Our new facility will also offer new employment and training opportunities in Ellesmere Port and the wider Merseyside region.
# 762
# 43 Comments
# Like
# Comment
# Share
# Copy
# LinkedIn
# Facebook
# Twitter
# To view or add a comment,
# sign in
# C&W Chamber International Trade Hub
# 113 followers
# 2mo
# Report this post
# EXPORTING STARTS HERE | Driving Growth in Coventry
#
# We’re thrilled to launch a new export support program designed to help Coventry businesses take their success to the global stage. 🌍
#
# Why export?
# 💡 Boost your business growth and profits.
# 💡 Strengthen Coventry’s economy.
# 💡 Put our city on the global map.
#
# Our Exporting Starts Here programme celebrates Coventry’s innovative spirit and ambition, helping businesses break old stereotypes and drive our city’s reputation forward.
#
# Whether you’re just starting or ready to expand into new markets, this FREE program includes:
# ✅ 1:1 expert advice tailored to your business needs
# ✅ Insights to identify new market opportunities
# ✅ Training and resources to simplify international trade
#
# Keely Hancox from the Coventry and Warwickshire Chamber of Commerce says: “We are absolutely thrilled that this new support is available to businesses across our patch. Exporting benefits individual businesses, the local economy and UK plc and that is why we want to encourage companies who have never traded internationally to get in touch to see how they can benefit from this help. It could be a game changer for them.”
#
# 📲 Get started today:
# https://lnkd.in/eeW54yDG
# *The project is funded by the West Midlands Combined Authority (WMCA) and the UK Shared Prosperity Fund (UKSPF), and delivered by the Coventry & Warwickshire, Black Country, and Greater Birmingham Chambers of Commerce.
# #ExportingStartsHere
# #UKSPF
# #Export
# #Growth
# …more
# 18
# 1 Comment
# Like
# Comment
# Share
# Copy
# LinkedIn
# Facebook
# Twitter
# To view or add a comment,
# sign in
# Economic Development Aberdeenshire
# 1,571 followers
# 3w
# Report this post
# ℹ️  Made in Scotland, Sold To The World
#
# Aberdeenshire
# #businesses
# who are new to, or considering selling internationally may be keen to attend a free in-person and online streamed event.
#
# Questions which the expert panellists will help answer include:
#
# •	How do I analyse international demand for my products and services?
# •	How do I identify suitable markets and how do I reach them?
# •	What regulations and legislation on exporting are there?
# •	What investment is required to export and what finance is available for businesses?
# •	How does shipping products work?
# •	How do I take advantage of the UK’s trade deals?
# •	What support is out there?
#
# Whatever the level of exporting experience, this event will help demystify challenges and highlight the benefits of selling products and services internationally.
#
# For more information and to register to attend either in person or online, please click this link:
# 🌐
# https://lnkd.in/euuNyxpx
# The event is planned to take place:
# 🗓️  9am - 1.30pm Thursday 27 February
# 📍  The Caledonian, Edinburgh, Curio Collection by Hilton (and online)
# #SoldToTheWorld
# #Roadshow
# #SellingInternationally
# #InternationalSales
# #Export
# #Exporting
# #Exporters
# #Trade
# #InternationalTrade
# #Markets
# #Regulations
# #Legislation
# #Shipping
# #UKTrade
# #BusinessAdvice
# #BusinessSupport
# Aberdeenshire Council
# 5
# 1 Comment
# Like
# Comment
# Share
# Copy
# LinkedIn
# Facebook
# Twitter
# To view or add a comment,
# sign in
# Seona Shand
# Chief Operating Officer at the Scottish Africa Business Association - helping Scottish businesses to access an unrivalled network between Scotland and Africa
# 7mo
# Report this post
# Our colleagues at the Edinburgh Chamber of Commerce are hosting a virtual trade mission to Florida, USA
#
# Why Florida?
#
# Scotland and the State of Florida have enjoyed longstanding, highly-developed ties in terms of language, culture, education, science, technology, transport, tourism, and commerce. Today the UK (including Scotland) is among Florida’s most significant economic partners, while Florida ranks among the top American states for British businesses.
#
# Florida’s $1.5 trillion economy is 14th in the world - bigger than those of the Netherlands and Mexico and about the same size as Spain. Home to more than 22 million residents, Florida is now the 3rd most populous U.S. state with one of the fastest growing economies.
#
# British exports to Florida totalled $2.6 billion in 2022, making the UK Florida’s 14th largest source of merchandise imports.
#
# Florida is a key point of entry for Scottish goods and services into the USA, both to serve the local Florida market, and as a gateway to other markets throughout the USA. As well as a gateway to access emerging markets in Latin America and the Caribbean.
#
# Key sectors in Florida:
# Food and Drink
# Creative industries
# Clean Tech
# Fintech
# Technology, media and telecommunications
# Manufacturing and transportation
# Life Sciences
# Professional services
#
# The mission is open to Scottish companies both members and non-members of the Edinburgh Chamber of Commerce in the above sectors. So why not apply?
#
# Programme highlights
#
# As part of this mission, you will take part in a market awareness session with our expert partners in marketing as well as two b2b meetings / connections based on your requirements, with the support from our partners in market.
#
# If you are interested in joining our virtual trade mission to Florida, please complete the application form and contact the team by e-mail
# international@edinburghchamber.co.uk
# or call the international team on 0131 221 2999 by Friday 23rd August for further information.
#
# In partnership with The Scottish Government and the Scottish Chambers of Commerce.
#
# Read more ➡️
# https://buff.ly/3KXFtJj
# The Scottish Chambers of Commerce Network is here to support your business - reach out to share your views, concerns and opportunities.
# #SCCnews
# #businesssupport
# #businessnetwork
# #businessvoice
# #businessleader
# Sign up for the Scottish Chambers of Commerce enewsletter at
# https://buff.ly/3CpsQnu
# Sign up for our Virtual Trade Mission to Florida, USA
# Like
# Comment
# Share
# Copy
# LinkedIn
# Facebook
# Twitter
# To view or add a comment,
# sign in
# Modestas Geiga
# Founder of Comversia
# 3mo
# Report this post
# 🌏 An Unforgettable Journey to China's Canton Fair with Steven Selikoff 🌏
#
# I had a great opportunity to join a private group led by Steven Selikoff for an unforgettable experience in China. Having read his book, The COMPLETE BOOK of Product Design, Development, Manufacturing, and Sales, I thought I knew what to expect. But walking through the massive halls of the Canton Fair with Steven in person—seeing his insights and strategies in action—was on a whole different level.
#
# Every moment was a learning experience, with Steven sharing the kind of knowledge that only comes from years of hands-on work with both Chinese manufacturers and US retailers.
#
# We toured factories together, seeing production processes up close, with Steven guiding us through the complexities of manufacturing. A tour to Guangzhou Port also gave us insight into logistics, revealing just how critical every step is from factory floor to market.
#
# Beyond these practical skills, Steven taught us the art of negotiation, showing us how to secure better terms with suppliers. He also introduced us to key contacts—IP lawyers, inspection companies, labs, and logistics experts—who are essential to making international business run smoothly.
#
# Steven’s teachings didn’t stop with China, either. We were taught about US retail trade, where Steven broke down what it takes to succeed in the American market. From understanding what US retailers want to navigating their standards and building strong partnerships, this knowledge was invaluable for anyone aiming to expand internationally.
#
# But perhaps the best part was the incredible people I met in the group. It was inspiring to be surrounded by other driven entrepreneurs, each of us learning and building connections that might last a lifetime.
# #CantonFair
# #ProductDevelopment
# #Sourcing
# #Manufacturing
# #SupplyChain
# #GlobalTrade
# #BusinessEducation
# 12
# Like
# Comment
# Share
# Copy
# LinkedIn
# Facebook
# Twitter
# To view or add a comment,
# sign in
# 516 followers
# 18 Posts
# View Profile
# Follow
# Explore topics
# Sales
# Marketing
# IT Services
# Business Administration
# HR Management
# Engineering
# Soft Skills
# See All
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# LinkedIn
# Never miss a beat on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app
#
#
#
# relevant post link
# Webpage Title:
# Arne Geschke on LinkedIn: #esg #climatechange
# Webpage Contents:
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Arne Geschke’s Post
# Arne Geschke
# Chief Data Officer and Co-Founder at FairSupply /
# Honorary Associate Professor at University of Sydney
# 4w
# Edited
# Report this post
# Truth hurts...
# #ESG
# #climatechange
# Joseph Gelfer
# sustainability strategist 🌳 green jobs advocate
# 4w
# Edited
# 🚨 Politicians are “precisely wrong, rather than being roughly right” on climate 🚨
#
# A new report from the
# Institute and Faculty of Actuaries
# (hardly a radical bunch prone to hyperbole) has dropped some substantial truth bombs on climate. This article notes:
#
# 💣 “The climate risk assessments being used by financial institutions, politicians and civil servants to assess the economic effects of global heating were wrong”
#
# 💣 “The report called for a paradigm shift by political leaders, civil servants and governments to tackle global heating”
#
# 💣 “policymakers are currently unable to hear warnings about risks to ongoing human progress or unwilling to act upon them with the urgency required.”
#
# So to bring this back to our ongoing discussions about whether we should DOUBLE-DOWN on sustainability-as-usual or RIP-IT-UP. The questions become:
#
# 🤔 Do you believe that the necessary “paradigm shift” is going to come from the political and professional class that has ignored the writing on the wall for decades❓
#
# 🤔 Do you believe they will be able to embrace the personal transformation required, as suggested by Žižek: “to abolish global warming means abolishing a part of yourself. Each of us will have to alter him/herself so completely that at the end s/he will hardly be recognizable as the same person”❓
#
# The answer is clearly, NO.
#
# 🔥 The political and professional class responsible for climate HAS FAILED
#
# 🔥 Their time IS OVER
#
# 🔥 They have TO GO
#
# The short answer is to establish a movement that mobilises the issues and mood of our time (climate populism 😎) and take over the job of national and global governance 💚 🌍
# 5
# Like
# Comment
# Share
# Copy
# LinkedIn
# Facebook
# Twitter
# To view or add a comment,
# sign in
# More Relevant Posts
# Joseph Gelfer
# sustainability strategist 🌳 green jobs advocate
# 4w
# Edited
# Report this post
# 🚨 Politicians are “precisely wrong, rather than being roughly right” on climate 🚨
#
# A new report from the
# Institute and Faculty of Actuaries
# (hardly a radical bunch prone to hyperbole) has dropped some substantial truth bombs on climate. This article notes:
#
# 💣 “The climate risk assessments being used by financial institutions, politicians and civil servants to assess the economic effects of global heating were wrong”
#
# 💣 “The report called for a paradigm shift by political leaders, civil servants and governments to tackle global heating”
#
# 💣 “policymakers are currently unable to hear warnings about risks to ongoing human progress or unwilling to act upon them with the urgency required.”
#
# So to bring this back to our ongoing discussions about whether we should DOUBLE-DOWN on sustainability-as-usual or RIP-IT-UP. The questions become:
#
# 🤔 Do you believe that the necessary “paradigm shift” is going to come from the political and professional class that has ignored the writing on the wall for decades❓
#
# ...
# Removing or replacing null values
# 4m 33s
# 5. Power BI and R
# 5. Power BI and R
# (Locked)
# Setting up R in Power Query Editor
# 5m 16s
# (Locked)
# Creating custom code with R standard visual
# 4m 34s
# (Locked)
# Challenge: Power BI
# 26s
# (Locked)
# Solution: Power BI
# 7m 5s
# Conclusion
# Conclusion
# (Locked)
# Next steps
# 1m 13s
# What’s included
# Practice while you learn
# 1 exercise file
# Test your knowledge
# 5 quizzes
# Learn on the go
# Access on tablet and phone
# Similar courses
# 1h 40m
# Data Visualization for Data Analysis and Analytics (2020)
# 2h 30m
# Python Data Analysis (2020)
# Download courses
# Use your iOS or Android LinkedIn Learning app, and watch courses on your mobile device without an internet connection.
# *
# Price may change based on profile and billing country information entered during Sign In or Registration
# Explore Business Topics
# Business Analysis and Strategy
# Business Software and Tools
# Career Development
# Customer Service
# Diversity, Equity, and Inclusion (DEI)
# Finance and Accounting
# Human Resources
# Leadership and Management
# Marketing
# Professional Development
# Project Management
# Sales
# Small Business and Entrepreneurship
# Training and Education
# See all
# Explore Creative Topics
# AEC
# Animation and Illustration
# Audio and Music
# Graphic Design
# Motion Graphics and VFX
# Photography
# Product and Manufacturing
# User Experience
# Video
# Visualization and Real-Time
# Web Design
# See all
# Explore Technology Topics
# Artificial Intelligence (AI)
# Cloud Computing
# Cybersecurity
# Data Science
# Database Management
# DevOps
# Hardware
# IT Help Desk
# Mobile Development
# Network and System Administration
# Software Development
# Web Development
# See all
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
#
#
#
# relevant learning course link
# Webpage Title:
# Practical Database Design: Implementing Responsible Data Solutions with SQL Querying Online Class | LinkedIn Learning, formerly Lynda.com
# Webpage Contents:
# Skip to main content
# Learning
# LinkedIn Learning
# Search skills, subjects, or software
# Expand search
# This button displays the currently selected search type. When expanded it provides a list of search options that will switch the search inputs to match the current selection.
# Jobs
# People
# Learning
# Clear text
# Clear text
# Clear text
# Clear text
# Clear text
# Start free trial
# Sign in
# Solutions for:
# Business
# Higher Education
# Government
# Buy for my team
# All topics
# Business
# Business Software and Tools
# Data Analysis
# Preview
# Practical Database Design: Implementing Responsible Data Solutions with SQL Querying
# With Dr. Brandeis Marshall
# Liked by 87 users
# Duration: 2h 15m
# Skill level: Intermediate
# Released: 6/25/2024
# Start my 1-month free trial
# Buy for my team
# Course details
# In this hands-on course, learn the fundamental concepts underlying database system design, including not only the design of applications using databases, but also covering the fundamental implementation techniques used in database systems. Instructor Brandeis Marshall takes you through a practical application of database design, database implementation, and data querying to determine when SQL querying is more appropriate. Learn how to develop effective SQL queries and leverage SQL as part of your responsible/ethical data practices. Brandeis takes you through the full arc of a database project, and finishes the course with a project that lets you apply all you’ve learned.
# Show more
# Show less
# Skills you’ll gain
# SQL
# Data Management
# Database Systems
# Database Design
# Earn a sharable certificate
# Share what you’ve learned, and be a standout professional in your desired industry with a certificate showcasing your knowledge gained from the course.
# Learning
# LinkedIn Learning
# Certificate of Completion
# Showcase on your LinkedIn profile under “Licenses and Certificate” section
# Download or print out as PDF to share with others
# Share as image online to demonstrate your skill
# Meet the instructor
# Dr. Brandeis Marshall
# I help keep our society data-literate and people-centered. Ask me how you can support Black Women in Data.
# Learner reviews
# 4.6
# out of 5
# 42 ratings
# How are ratings calculated?
# The overall rating is calculated using the average of submitted ratings. Ratings and reviews can only be submitted when non-anonymous learners complete at least 40% of the course. This helps us avoid fake reviews and spam.
# 5 star
# Current value: 31
# 74%
# 4 star
# Current value: 7
# 17%
# 3 star
# Current value: 2
# 5%
# 2 star
# Current value: 2
# 5%
# 1 star
# Current value: 0
# 0%
# Liberty Ikpeogu
# Liberty Ikpeogu
# Student Technician at Georgia State University J. Mack Robinson College of Business| 1913 Society Ambassador
# 5/5
# September 17, 2024
# Wonderful experience. Great for beginners. Highly recommend!!
# Helpful
# ·
# Report
# Minh Nguyen
# Minh Nguyen
# --
# 3/5
# September 15, 2024
# need more visual and example
# Helpful
# ·
# Report
# Christian Wiah
# Christian Wiah
# --
# 2/5
# August 10, 2024
# Great course but I needed a little bit of vibes. I thought I was learning the English Language. Overall, some key concepts and I derived the benefits from the course. Great!
# Helpful
# ·
# Report
# Contents
# Introduction
# Introduction
# Designing and implementing a data model
# 1m 3s
# What you should know
# 1m 29s
# 1. Business Rule Development
# 1. Business Rule Development
# How databases help businesses
# 4m 29s
# (Locked)
# The DIKW Model
# 5m 8s
# (Locked)
# What's a business rule?
# 4m 10s
# (Locked)
# A business rule vs. a business operation
# 3m 5s
# (Locked)
# A business rule vs. a business practice
# 3m 20s
# (Locked)
# A business rule vs. a business policy
# 3m 2s
# (Locked)
# Example business rules
# 1m 55s
# 2. Database Design
# 2. Database Design
# Entities and relationships
# 3m 11s
# (Locked)
# Cardinalities
# 3m 52s
# (Locked)
# Scoping the database requirements
# 3m 8s
# (Locked)
# Analyzing the overall data requirements
# 4m
# (Locked)
# Connecting entities, relationships, and business rules
# 4m 57s
# (Locked)
# Identifying data integrity requirements
# 4m 16s
# 3. Data Generation and Datasets
# 3. Data Generation and Datasets
# (Locked)
# The data you're given: Now what?
# 3m 53s
# (Locked)
# Asking questions of the data
# 3m 52s
# (Locked)
# The data you're creating: Pros and cons
# 3m 47s
# (Locked)
# Asking questions of your made-up data
# 3m 22s
# 4. Database Implementation
# 4. Database Implementation
# (Locked)
# Overview of MySQL Workbench
# 4m 9s
# (Locked)
# Creating entities in MySQL Workbench
# 5m 25s
# (Locked)
# Creating relationships in MySQL Workbench
# 11m 8s
# (Locked)
# Confirming identifying and non-identifying relationships
# 5m 3s
# (Locked)
# Creating the database schema
# 3m 55s
# 5. SQL Querying
# 5. SQL Querying
# (Locked)
# Overview of the SELECT statement
# 4m 20s
# (Locked)
# Another toy dataset
# 9m 4s
# (Locked)
# SELECT-FROM clauses
# 8m 46s
# (Locked)
# SELECT-FROM-WHERE clauses
# 8m 29s
# (Locked)
# GROUP BY and ORDER BY clauses
# 6m 10s
# 6. Final Project
# 6. Final Project
# (Locked)
# Bringing it all together
# 1m 29s
# (Locked)
# Final project: The Brainery
# 1m 7s
# Conclusion
# Conclusion
# (Locked)
# Next steps
# 53s
# What’s included
# Practice while you learn
# 1 exercise file
# Test your knowledge
# 5 quizzes
# Learn on the go
# Access on tablet and phone
# Similar courses
# 1h 18m
# Database Design Fundamentals
# 1h 19m
# Hands-On Introduction: SQL
# Download courses
# Use your iOS or Android LinkedIn Learning app, and watch courses on your mobile device without an internet connection.
# *
# Price may change based on profile and billing country information entered during Sign In or Registration
# Explore Business Topics
# Business Analysis and Strategy
# Business Software and Tools
# Career Development
# Customer Service
# Diversity, Equity, and Inclusion (DEI)
# Finance and Accounting
# Human Resources
# Leadership and Management
# Marketing
# Professional Development
# Project Management
# Sales
# Small Business and Entrepreneurship
# Training and Education
# See all
# Explore Creative Topics
# AEC
# Animation and Illustration
# Audio and Music
# Graphic Design
# Motion Graphics and VFX
# Photography
# Product and Manufacturing
# User Experience
# Video
# Visualization and Real-Time
# Web Design
# See all
# Explore Technology Topics
# Artificial Intelligence (AI)
# Cloud Computing
# Cybersecurity
# Data Science
# Database Management
# DevOps
# Hardware
# IT Help Desk
# Mobile Development
# Network and System Administration
# Software Development
# Web Development
# See all
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
#
#
#
# relevant learning course link
# Webpage Title:
# From Excel to SQL Online Class | LinkedIn Learning, formerly Lynda.com
# Webpage Contents:
# Skip to main content
# Learning
# LinkedIn Learning
# Search skills, subjects, or software
# Expand search
# This button displays the currently selected search type. When expanded it provides a list of search options that will switch the search inputs to match the current selection.
# Jobs
# People
# Learning
# Clear text
# Clear text
# Clear text
# Clear text
# Clear text
# Start free trial
# Sign in
# Solutions for:
# Business
# Higher Education
# Government
# Buy for my team
# All topics
# Business
# Business Software and Tools
# Data Analysis
# Preview
# From Excel to SQL
# With James Parkin and Madecraft
# Liked by 5,719 users
# Duration: 1h 24m
# Skill level: Beginner
# Released: 2/2/2021
# Start my 1-month free trial
# Buy for my team
# Course details
# Data is powerful, and the ability to access it quickly and accurately is important. In this course, instructor James Parkin helps you use your existing Excel skills to master the basics of working with data in SQL, one of the most common languages for database wrangling. James shows you how to set up your environment for SQL and shares some differences between spreadsheets and databases. He steps through SQL basics that you need to know to access and identify the data you need. In both Excel and SQL, you work with functions. James covers several, including SUM, AVERAGE, MIN, MAX, COUNT. He explains different methods of sorting, grouping, and organizing your data in SQL. James concludes by showing you how to use joins, VLOOKUP, HLOOKUP, and XLOOKUP to combine your data.
# This course was created by
# Madecraft
# . We are pleased to host this training in our library.
# Show more
# Show less
# Skills you’ll gain
# SQL
# Microsoft Excel
# Meet the instructors
# James Parkin
# Senior Software Engineer working with Javascript and React
# Madecraft
# Learner reviews
# 4.8
# out of 5
# 3,085 ratings
# How are ratings calculated?
# The overall rating is calculated using the average of submitted ratings. Ratings and reviews can only be submitted when non-anonymous learners complete at least 40% of the course. This helps us avoid fake reviews and spam.
# 5 star
# Current value: 2,552
# 83%
# 4 star
# Current value: 464
# 15%
# 3 star
# Current value: 63
# 2%
# 2 star
# Current value: 1
# <1%
# 1 star
# Current value: 5
# <1%
# Onias Chikwata, FCCA, M. Comm,
# Onias Chikwata, FCCA, M. Comm,
# | Finance Specialist | Finance and Budget Officer | Data Analyst/Scientist | Project Manager | Grants Officer | Accountant
# 5/5
# November 25, 2024
# It was intuitive. I need more from these instructors. They have made me feel confident
# Helpful
# ·
# Report
# Karen L. Teufer
# Karen L. Teufer
# Health Information Management Manager | Coding Manager | MSHIM, RHIA, HCS-D, CDIP in Progress
# 5/5
# November 14, 2024
# Learned a lot!  Great for beginners.
# Helpful
# ·
# Report
# Gualberto Antonio Hernández Chacin
# Gualberto Antonio Hernández Chacin
# | IT Project Leader | IT Infrastructure  | IT Systems Specialist | Technical Support | Customer Service |
# 5/5
# October 5, 2024
# Excelente explicación del tema.
# Helpful
# ·
# Report
# Contents
# Introduction
# Introduction
# Moving from Excel to SQL
# 1m 3s
# Setting up your environment for SQL
# 3m 8s
# 1. Comparing Excel and SQL
# 1. Comparing Excel and SQL
# (Locked)
# Spreadsheets vs. databases
# 2m 41s
# (Locked)
# What is SQL?
# 2m 53s
# 2. SQL Basics
# 2. SQL Basics
# (Locked)
# Viewing data in SQL
# 3m 43s
# (Locked)
# Identifying columns in SQL
# 3m 13s
# (Locked)
# Filtering rows in SQL
# 5m 28s
# (Locked)
# Combining filters in SQL
# 8m 35s
# (Locked)
# Limiting results in SQL
# 3m 25s
# (Locked)
# Comparison operators in SQL
# 2m 8s
# (Locked)
# The LIKE operator in SQL
# 2m 17s
# 3. Working with Functions
# 3. Working with Functions
# (Locked)
# Using SUM in SQL
# 3m 14s
# (Locked)
# AVERAGE, MIN, MAX, and COUNT in SQL
# 4m 17s
# (Locked)
# Finding unique values in SQL
# 3m 33s
# (Locked)
# UPPER, LOWER, and LENGTH in SQL
# 2m
# 4. Organizing Data
# 4. Organizing Data
# (Locked)
# Sorting data
# 4m 21s
# (Locked)
# Grouping data
# 4m 1s
# (Locked)
# Using a pivot table in SQL
# 3m 26s
# (Locked)
# Subqueries in SQL
# 3m 27s
# (Locked)
# Advanced subqueries in SQL
# 5m 37s
# 5. Combining Data
# 5. Combining Data
# (Locked)
# Using JOINs
# 3m 22s
# (Locked)
# The different types of JOINs
# 5m 5s
# (Locked)
# Using VLOOKUP, HLOOKUP, XLOOKUP in SQL
# 2m 22s
# Conclusion
# Conclusion
# (Locked)
# Taking your SQL skills to the next level
# 1m 26s
# What’s included
# Practice while you learn
# 1 exercise file
# Test your knowledge
# 5 quizzes
# Learn on the go
# Access on tablet and phone
# Similar courses
# 2h 31m
# Relational Databases Essential Training
# Download courses
# Use your iOS or Android LinkedIn Learning app, and watch courses on your mobile device without an internet connection.
# *
# Price may change based on profile and billing country information entered during Sign In or Registration
# Explore Business Topics
# Business Analysis and Strategy
# Business Software and Tools
# Career Development
# Customer Service
# Diversity, Equity, and Inclusion (DEI)
# Finance and Accounting
# Human Resources
# Leadership and Management
# Marketing
# Professional Development
# Project Management
# Sales
# Small Business and Entrepreneurship
# Training and Education
# See all
# Explore Creative Topics
# AEC
# Animation and Illustration
# Audio and Music
# Graphic Design
# Motion Graphics and VFX
# Photography
# Product and Manufacturing
# User Experience
# Video
# Visualization and Real-Time
# Web Design
# See all
# Explore Technology Topics
# Artificial Intelligence (AI)
# Cloud Computing
# Cybersecurity
# Data Science
# Database Management
# DevOps
# Hardware
# IT Help Desk
# Mobile Development
# Network and System Administration
# Software Development
# Web Development
# See all
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language

# %%
system_prompt_profile = "You are an assistant that analyzes the contents of a professional profile, \
focusing on a thorough profile analysis. Provide a concise overview of the person’s background, \
expertise, core values, leadership style (if applicable), and relevant accomplishments. Respond in \
Markdown format. Include any details that would be helpful for a job searcher seeking to connect \
with this individual, such as insights into day-to-day responsibilities, professional development, \
or notable achievements, if available."

# %%
def get_profile_analysis(profile_name, url):
    user_prompt = f"You are looking at a professional named: {profile_name}\n"
    user_prompt += (
        "Here are the contents of their LinkedIn page and any other relevant pages. "
        "Use this information to create a concise overview of this individual's background, expertise, "
        "core values, leadership style (if applicable), and relevant accomplishments. "
        "Include any insights that would be helpful for someone seeking to connect with this person, "
        "such as day-to-day responsibilities, professional development, or notable achievements. "
        "Respond in Markdown.\n"
    )
    user_prompt += get_all_profile_details(url)
    user_prompt = user_prompt[:20_000]  # Truncate if more than 20,000 characters
    return user_prompt

# %%
def create_profile_analysis(profile_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt_profile},
            {"role": "user", "content": get_profile_analysis(profile_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
create_profile_analysis("Ed Donner", "https://www.linkedin.com/in/eddonner/")
# Out:
# Found links: {'links': [{'type': 'relevant profile link', 'url': 'https://www.linkedin.com/in/eddonner'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/posts/mert-adal%C4%B1-120726229_as-an-junior-mobile-developer-with-a-background-activity-7295793892308746240-MCc7'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/posts/sanjeev-b-ba4078247_ai-agenticai-openai-activity-7295082083398336513-4Lyl'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/posts/graphnick_how-easy-is-it-to-scrape-a-webpage-with-ai-activity-7296188959259340800-pfLE'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/in/gregtoroosian?trk=public_profile_relatedPosts_face-pile-cta'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/posts/gregtoroosian_machineminds-techpodcast-ai-activity-7231423440698662912-cRZ2?trk=public_profile_relatedPosts'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/in/jonathon-johnson-0623ab152?trk=public_profile_relatedPosts_face-pile-cta'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/posts/jonathon-johnson-0623ab152_startup-artificialintelligence-gpu-activity-7229478833496768512-Tc9Y?trk=public_profile_relatedPosts'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/in/katerinastroponiati?trk=public_profile_relatedPosts_face-pile-cta'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/posts/katerinastroponiati_what-our-deal-flow-reveals-about-founders-activity-7276987334909149184-9MmM?trk=public_profile_relatedPosts'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/in/ed-donner-ba682119?trk=public_profile_samename-profile'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/in/ed-donner-3a950587?trk=public_profile_samename-profile'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/in/ed-donner-1546766b?trk=public_profile_samename-profile'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/in/ed-donner-3b38742b9?trk=public_profile_samename-profile'}, {'type': 'relevant profile link', 'url': 'https://www.linkedin.com/pub/dir/Ed/Donner/us-0-United-States?trk=public_profile_samename-see-all'}]}
# # Profile Overview: Ed Donner
#
# ## Background
# Ed Donner is a seasoned technology leader and entrepreneur based in New York City. He has a strong academic foundation with education from the University of Oxford. His career has been marked by a focus on leveraging artificial intelligence (AI) to innovate within the travel industry, specifically as a co-founder of Simplified.Travel.
#
# ## Expertise
# - **Technology Leadership**: Extensive experience in leading technological initiatives from conception through execution, particularly in the application of AI in travel.
# - **Entrepreneurship**: Proven track record of building and scaling startups, with a focus on creating user-centric technologies.
# - **AI Applications**: Deep understanding of how AI can transform business processes, particularly in streamlining travel experiences through personalization and automation.
#
# ## Core Values
# Ed emphasizes values such as innovation, customer-centricity, and adaptability in the face of rapidly changing technologies. He appears to advocate for the responsible deployment of AI in ways that genuinely benefit end-users.
#
# ## Leadership Style
# Ed is likely to adopt a collaborative leadership style, fostering open communication and fostering a team-oriented environment. His background suggests he values input from diverse perspectives to drive creative solutions and encourage team innovation.
#
# ## Relevant Accomplishments
# - **Simplified.Travel**: Co-founder of a startup aimed at enhancing travel experiences through innovative tech solutions.
# - **AI Innovations**: Actively involved in applying AI technologies to enhance operational efficiencies and customer experiences in the travel sector.
#
# ## Insights for Connection
# - **Day-to-Day Responsibilities**: Involvement in strategic planning, development cycles of new technologies, and team management at Simplified.Travel.
# - **Professional Development**: Ed stays updated on AI trends and their business applications, participating actively in discussions and publications within his network.
# - **Notable Achievements**: While no specific metrics are detailed in the available information, his impact in the tech domain, especially with Simplified.Travel, indicates significant contributions to both the industry and user engagement.
#
# ## Networking Opportunities
# Individuals looking to connect with Ed should consider:
# - Engaging in discussions about AI and its practical implications within travel or technology.
# - Sharing insights or innovations that relate to customer experience enhancement through technology.
# - Asking about his experiences and insights on building a tech startup in the competitive landscape of AI and travel.
#
# By connecting with Ed, peers and aspiring entrepreneurs can gain valuable insights from his journey and expertise in harnessing technology for transformational change.
